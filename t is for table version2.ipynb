# %% [markdown]
# ___
# # t is for Table
#
# This is a demo jupyter notebook of the t. library in https://github.com/al3xandr3/T
#
# ___

# %% [markdown]
# ## Import libraries

# %%
## remove this, this is for my personal pc setup
import sys; import os; sys.path.append(os.path.expanduser('~/Google Drive/my/projects/t/'))

# %%
import matplotlib
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

import pandas   as pd
import operator as op

import numpy             as np
import seaborn           as sns
from datetime import datetime

import pyscope
from pyscope import read_ss

from IPython.display import IFrame

import t as t
#from t import * # want T to be accessible

# %load_ext autoreload
# %autoreload

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ## Data

# %%
df = pd.DataFrame({'user':['k','j','k','t','k','j'] \
                 , 'date': [datetime.strptime(d, '%Y-%m-%d') for d in ['2018-10-16', '2018-10-16', '2018-10-17', '2018-10-17', '2018-10-18', '2018-10-19']]
                 , 'period':['before', 'before', 'before', 'before', 'after','after'] \
                 , 'cohort':['control','control','control','control','control','control'] \
                 , 'isLabel':[0,1,1,1,0,1]
                 , 'kpi':[5,6,7,8,9,10]})

# %% [markdown]
# Building a T( ) is the same

# %%
t2 = pd.DataFrame({'user':['k','j','k','t','k','j'] \
                 , 'date': [datetime.strptime(d, '%Y-%m-%d') for d in ['2018-10-16', '2018-10-16', '2018-10-17', '2018-10-17', '2018-10-18', '2018-10-19']]
                 , 'period':['before', 'before', 'before', 'before', 'after','after'] \
                 , 'cohort':['control','control','control','control','control','control'] \
        , 'isLabel':[0,1,1,1,0,1]         
        , 'kpi':[5,6,7,8,9,10]})

# %% [markdown]
# ## Table manipulations

# %%
t.select(df, "kpi")
# Out:
#    kpi
# 0    5
# 1    6
# 2    7
# 3    8
# 4    9
# 5   10

# %%
t.where(df, "isLabel", 0)
# Out:
#   user       date  period   cohort  isLabel  kpi
# 0    k 2018-10-16  before  control        0    5
# 4    k 2018-10-18   after  control        0    9

# %%
t.where(df, "isLabel", 0, op.ne) # not equal
# Out:
#   user       date  period   cohort  isLabel  kpi
# 1    j 2018-10-16  before  control        1    6
# 2    k 2018-10-17  before  control        1    7
# 3    t 2018-10-17  before  control        1    8
# 5    j 2018-10-19   after  control        1   10

# %%
t.relabel(df, "isLabel", "theLabel")
# Out:
#   user       date  period   cohort  theLabel  kpi
# 0    k 2018-10-16  before  control         0    5
# 1    j 2018-10-16  before  control         1    6
# 2    k 2018-10-17  before  control         1    7
# 3    t 2018-10-17  before  control         1    8
# 4    k 2018-10-18   after  control         0    9
# 5    j 2018-10-19   after  control         1   10

# %%
t.row(df, 0)
# Out:
# array(['k', Timestamp('2018-10-16 00:00:00'), 'before', 'control', 0, 5],
#       dtype=object)

# %%
t.group(df, "user")
# Out:
#    user
# k     3
# j     2
# t     1

# %%
t.sort(df, "kpi", ascending=False)
# Out:
#   user       date  period   cohort  isLabel  kpi
# 5    j 2018-10-19   after  control        1   10
# 4    k 2018-10-18   after  control        0    9
# 3    t 2018-10-17  before  control        1    8
# 2    k 2018-10-17  before  control        1    7
# 1    j 2018-10-16  before  control        1    6
# 0    k 2018-10-16  before  control        0    5

# %%
# Style
numeric_col_mask = df.dtypes.apply(lambda d: issubclass(np.dtype(d).type, np.number))

df.style.format(lambda x: '{:,.0f}'.format(x) if x > 1e3 else '{:,.2f}'.format(x), # format the numeric values
                subset=pd.IndexSlice[:,df.columns[numeric_col_mask]])
# Out:
# <style  type="text/css" >
# </style><table id="T_6e98e3da_9e4e_11ea_83c0_2816a8574ad8" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >user</th>        <th class="col_heading level0 col1" >date</th>        <th class="col_heading level0 col2" >period</th>        <th class="col_heading level0 col3" >cohort</th>        <th class="col_heading level0 col4" >isLabel</th>        <th class="col_heading level0 col5" >kpi</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6e98e3da_9e4e_11ea_83c0_2816a8574ad8level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_6e98e3da_9e4e_11ea_83c0_2816a8574ad8row0_col0" class="data row0 col0" >k</td>
#                         <td id="T_6e98e3da_9e4e_11ea_83c0_2816a8574ad8row0_col1" class="data row0 col1" >2018-10-16 00:00:00</td>
#                         <td id="T_6e98e3da_9e4e_11ea_83c0_2816a8574ad8row0_col2" class="data row0 col2" >before</td>
#                         <td id="T_6e98e3da_9e4e_11ea_83c0_2816a8574ad8row0_col3" class="data row0 col3" >control</td>
#                         <td id="T_6e98e3da_9e4e_11ea_83c0_2816a8574ad8row0_col4" class="data row0 col4" >0.00</td>
#                         <td id="T_6e98e3da_9e4e_11ea_83c0_2816a8574ad8row0_col5" class="data row0 col5" >5.00</td>
#             </tr>
#             <tr>
#                         <th id="T_6e98e3da_9e4e_11ea_83c0_2816a8574ad8level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_6e98e3da_9e4e_11ea_83c0_2816a8574ad8row1_col0" class="data row1 col0" >j</td>
#                         <td id="T_6e98e3da_9e4e_11ea_83c0_2816a8574ad8row1_col1" class="data row1 col1" >2018-10-16 00:00:00</td>
#                         <td id="T_6e98e3da_9e4e_11ea_83c0_2816a8574ad8row1_col2" class="data row1 col2" >before</td>
#                         <td id="T_6e98e3da_9e4e_11ea_83c0_2816a8574ad8row1_col3" class="data row1 col3" >control</td>
#                         <td id="T_6e98e3da_9e4e_11ea_83c0_2816a8574ad8row1_col4" class="data row1 col4" >1.00</td>
#                         <td id="T_6e98e3da_9e4e_11ea_83c0_2816a8574ad8row1_col5" class="data row1 col5" >6.00</td>
#             </tr>
#             <tr>
#                         <th id="T_6e98e3da_9e4e_11ea_83c0_2816a8574ad8level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_6e98e3da_9e4e_11ea_83c0_2816a8574ad8row2_col0" class="data row2 col0" >k</td>
#                         <td id="T_6e98e3da_9e4e_11ea_83c0_2816a8574ad8row2_col1" class="data row2 col1" >2018-10-17 00:00:00</td>
#                         <td id="T_6e98e3da_9e4e_11ea_83c0_2816a8574ad8row2_col2" class="data row2 col2" >before</td>
#                         <td id="T_6e98e3da_9e4e_11ea_83c0_2816a8574ad8row2_col3" class="data row2 col3" >control</td>
#                         <td id="T_6e98e3da_9e4e_11ea_83c0_2816a8574ad8row2_col4" class="data row2 col4" >1.00</td>
#                         <td id="T_6e98e3da_9e4e_11ea_83c0_2816a8574ad8row2_col5" class="data row2 col5" >7.00</td>
#             </tr>
#             <tr>
#                         <th id="T_6e98e3da_9e4e_11ea_83c0_2816a8574ad8level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_6e98e3da_9e4e_11ea_83c0_2816a8574ad8row3_col0" class="data row3 col0" >t</td>
#                         <td id="T_6e98e3da_9e4e_11ea_83c0_2816a8574ad8row3_col1" class="data row3 col1" >2018-10-17 00:00:00</td>
#                         <td id="T_6e98e3da_9e4e_11ea_83c0_2816a8574ad8row3_col2" class="data row3 col2" >before</td>
#                         <td id="T_6e98e3da_9e4e_11ea_83c0_2816a8574ad8row3_col3" class="data row3 col3" >control</td>
#                         <td id="T_6e98e3da_9e4e_11ea_83c0_2816a8574ad8row3_col4" class="data row3 col4" >1.00</td>
#                         <td id="T_6e98e3da_9e4e_11ea_83c0_2816a8574ad8row3_col5" class="data row3 col5" >8.00</td>
#             </tr>
#             <tr>
#                         <th id="T_6e98e3da_9e4e_11ea_83c0_2816a8574ad8level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_6e98e3da_9e4e_11ea_83c0_2816a8574ad8row4_col0" class="data row4 col0" >k</td>
#                         <td id="T_6e98e3da_9e4e_11ea_83c0_2816a8574ad8row4_col1" class="data row4 col1" >2018-10-18 00:00:00</td>
#                         <td id="T_6e98e3da_9e4e_11ea_83c0_2816a8574ad8row4_col2" class="data row4 col2" >after</td>
#                         <td id="T_6e98e3da_9e4e_11ea_83c0_2816a8574ad8row4_col3" class="data row4 col3" >control</td>
#                         <td id="T_6e98e3da_9e4e_11ea_83c0_2816a8574ad8row4_col4" class="data row4 col4" >0.00</td>
#                         <td id="T_6e98e3da_9e4e_11ea_83c0_2816a8574ad8row4_col5" class="data row4 col5" >9.00</td>
#             </tr>
#             <tr>
#                         <th id="T_6e98e3da_9e4e_11ea_83c0_2816a8574ad8level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_6e98e3da_9e4e_11ea_83c0_2816a8574ad8row5_col0" class="data row5 col0" >j</td>
#                         <td id="T_6e98e3da_9e4e_11ea_83c0_2816a8574ad8row5_col1" class="data row5 col1" >2018-10-19 00:00:00</td>
#                         <td id="T_6e98e3da_9e4e_11ea_83c0_2816a8574ad8row5_col2" class="data row5 col2" >after</td>
#                         <td id="T_6e98e3da_9e4e_11ea_83c0_2816a8574ad8row5_col3" class="data row5 col3" >control</td>
#                         <td id="T_6e98e3da_9e4e_11ea_83c0_2816a8574ad8row5_col4" class="data row5 col4" >1.00</td>
#                         <td id="T_6e98e3da_9e4e_11ea_83c0_2816a8574ad8row5_col5" class="data row5 col5" >10.00</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## EDA

# %%
t.variance(df, "kpi")
# Out:
# 2.9166666666666665

# %%
t.std(df, "kpi")
# Out:
# 1.707825127659933

# %%
t.avg(df, "kpi")
# Out:
# 7.5

# %%
t.median(df, "kpi")
# Out:
# 7.5

# %%
t.showna(pd.DataFrame(np.random.normal(size=(37,2)), columns=['A', 'B'] )) # show NA's

# %% [markdown]
# ## Histogram

# %%
df = pd.DataFrame(np.random.normal(size=(37,2)), columns=['A', 'B'])

# %%
t.histogram(df,'A')

# %%
t.histogram(df, 'B', xlabel="TITLE")

# %% [markdown]
# ## Decile

# %%
df = pd.DataFrame(np.arange(1000), columns=['kpi'])

# %%
t.decile(df, 'kpi')
# Out:
#    decile  median    avg  count    min    max
# 0       1    49.5   49.5  100.0    0.0   99.0
# 1       2   149.5  149.5  100.0  100.0  199.0
# 2       3   249.5  249.5  100.0  200.0  299.0
# 3       4   349.5  349.5  100.0  300.0  399.0
# 4       5   449.5  449.5  100.0  400.0  499.0
# 5       6   549.5  549.5  100.0  500.0  599.0
# 6       7   649.5  649.5  100.0  600.0  699.0
# 7       8   749.5  749.5  100.0  700.0  799.0
# 8       9   849.5  849.5  100.0  800.0  899.0
# 9      10   949.5  949.5  100.0  900.0  999.0

# %%
t.ecdf(df, "kpi") # shows the: 5%, 50% and 95% percentile

# %% [markdown]
# ## Stat Inference, CI

# %%
df = pd.DataFrame(np.random.normal(size=(37,2)), columns=['A', 'B'])

# %%
t.ci_mean(df, 'A')
# Out:
# {'mean': 0.15956370699968478,
#  '95% conf int of mean': array([-0.21434937,  0.51462124])}

# %%
t.ci_median(df, 'A')
# Out:
# {'median': 0.0034330778131037155,
#  '95% conf int of median': array([-0.27612878,  0.76481409])}

# %%
df = pd.DataFrame( np.hstack((np.ones(200), np.zeros(800) )), columns=['isLabel'] )

# %%
# test of proportion
t.ci_proportion(df, 'isLabel')
# Out:
# {'Proportion of 1s': 0.2, '95% Conf. Int. of Proportion': [0.176, 0.225]}

# %% [markdown]
# ## Hypothesis testing

# %%
a = pd.DataFrame(np.random.normal(0, size=(10,1)), columns=["values"])
a['label'] = '2'
b = pd.DataFrame(np.random.normal(1, size=(10,1)), columns=["values"])
b['label'] = '1'

k = pd.concat([a, b])
k.head()
# Out:
#      values label
# 0 -0.624170     2
# 1  1.062506     2
# 2  0.290493     2
# 3  0.103500     2
# 4 -0.380705     2

# %%
# %%time
t.hypothesis_mean_diff(k, "values", "label")
# Out:
# Wall time: 1min 12s
# {'Observed Difference': -1.612778823456965,
#  'p-value': 0.0041999999999999815,
#  'decision': 'Significant Difference',
#  'Null Hypothesis Bootstrap Differences': array([-0.10474825,  0.17472651,  0.1284113 , ..., -0.66393676,
#          0.45565019, -0.28961193])}

# %% [markdown]
# ## Model evaluations

# %%
actuals = [0, 1, 1, 0, 1]
predicted = [0, 1, 1, 0, 1]

# %%
t.confusion(actuals, predicted)
# Out:
# (           Pred: 0 Pred:   1  total
#  Actual: 0  TN= 2.0   FN= 0.0    2.0
#  Actual: 1  FP= 0.0   TP= 3.0    3.0
#  total            2         3    5.0,
#  '',
#  'Precision (Pre) =TP/(TP+FP)                      : 1.0',
#  'Recall    (Rec) =TP/(TP+FN)                      : 1.0',
#  'F1-score        =2*(Pre*Rec)/(Pre+Rec)           : 1.0',
#  'Accuracy        =(TP+TN)/Total                   : 1.0',
#  'F05-score       =1.25*(Pre*Rec)/((0.25*Pre)+Rec) : 1.0',
#  'F2-score        =5*(Pre*Rec)/((4*Pre)+Rec)       : 1.0')

# %%
t.roc(actuals, predicted)
# Out:
# [array([0., 0., 1.]), array([0., 1., 1.]), array([2, 1, 0])]

# %%
t.classification_score(actuals, predicted)
# Out:
# 1
